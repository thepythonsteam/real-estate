# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_test = pd.read_csv('../data/df_test_poi_salary_population.csv', compression='zip')

# %%
df_test.shape[0]
# Out:
# 8644

# %%
df_test = df_test.drop(columns=['Unnamed: 0'])

# %%
df_test = df_test.drop_duplicates(subset='id', keep='first')

# %%
df_test.head()
# Out:
#        city floor          id  osm_amenity_points_in_0.001  \
# 0     Курск   1.0  COL_289284                            7
# 3    Сургут   1.0  COL_289305                            8
# 6    Тюмень  -1.0  COL_289318                            3
# 9   Иркутск   1.0  COL_289354                            5
# 12    Курск   NaN  COL_289399                            8
#
#     osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                            55                            85
# 3                            70                           112
# 6                            28                            67
# 9                            76                           139
# 12                          105                           189
#
#     osm_amenity_points_in_0.01  osm_building_points_in_0.001  \
# 0                          117                             0
# 3                          140                             0
# ...

# %%
df_test.shape[0]
# Out:
# 2974

# %%
df_test.to_csv('../data/df_test_poi_salary_population.csv', compression='zip')
